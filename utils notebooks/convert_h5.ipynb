# %%
import tensorflow as tf
# Out:
# d:\WORK\xai\Explainability-AI\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
model = tf.keras.models.load_model('D:/WORK/xai/Explainability-AI/models/audio/my_vgg16.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.export('D:/WORK/xai/Explainability-AI/models/audio/vgg16')
# Out:
# INFO:tensorflow:Assets written to: D:/WORK/xai/Explainability-AI/models/audio/vgg16\assets
# INFO:tensorflow:Assets written to: D:/WORK/xai/Explainability-AI/models/audio/vgg16\assets
# Saved artifact at 'D:/WORK/xai/Explainability-AI/models/audio/vgg16'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='input_layer')]
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2405219137488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2405219138256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2405219139024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2405219138064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2405219138832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2405219138448: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
